# %% [markdown]
# # Instalacion e implementacion de Librerias

# %%
#Instalacion de librerias en el notebook
# !pip install pymongo pandas numpy matplotlib seaborn scikit-learn
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymongo-4.15.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.6 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.4

# %%
#Importacion de librerias necesarias
from pymongo import MongoClient
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Conexion a MongoDB

# %%
#Obtencion de IP publica del notebook
# !curl ipinfo.io/ip
# Out:
# 34.132.23.255

# %%
#Conexion a Mongo DB
uri = "mongodb+srv://fmmejiap_db_user:Fer99194805@cluster0.172zje5.mongodb.net/"
client = MongoClient(uri)
db = client["DisneylandRevs"]
collection = db["reviews"]
print("Conexión establecida con MongoDB")
# Out:
# Conexión establecida con MongoDB

# %%
#Creacion de un DatFrame con los datos del CSV
df = pd.read_csv('DisneylandReviews.csv', encoding="ISO-8859-1")
df.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %% [markdown]
# # Data Wrangling

# %%
#Verificamos que no existan valores nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.0+ MB

# %%
#Creamos un DataFrame para realizar cambios dentro de la estructura sin afetar el DF principal
df1 = pd.DataFrame(df)
#Eliminamos columnas que no van a ser necesarias dentro de la tabla Reviews
df1 = df1.drop(['Reviewer_Location','Branch'], axis=1)
df1.head()
# Out:
#    Review_ID  Rating Year_Month  \
# 0  670772142       4     2019-4
# 1  670682799       4     2019-5
# 2  670623270       4     2019-4
# 3  670607911       4     2019-4
# 4  670607296       4     2019-4
#
#                                          Review_Text
# 0  If you've ever been to Disneyland anywhere you...
# 1  Its been a while since d last time we visit HK...
# 2  Thanks God it wasn   t too hot or too humid wh...
# 3  HK Disneyland is a great compact park. Unfortu...
# 4  the location is not in the city, took around 1...

# %%
#Se encontraron registros con el valor missing en el atributo Year_Month, con esta validacion podemos observar la cantidad total de registros que contienen este valor
df_Date = pd.DataFrame(df1[df1['Year_Month'] == 'missing'])
df_Date.info()

#Almacenamos en un nuevo dataframe
df_DropDates = df1[df1['Year_Month'] != 'missing']
df_DropDates.info()


df_Date = pd.DataFrame(df_DropDates[df_DropDates['Year_Month'] == 'missing'])
df_Date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2613 entries, 269 to 42655
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review_ID    2613 non-null   int64
#  1   Rating       2613 non-null   int64
#  2   Year_Month   2613 non-null   object
#  3   Review_Text  2613 non-null   object
#  4   user_id      2613 non-null   object
#  5   parks_id     2613 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 142.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 40043 entries, 0 to 42117
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review_ID    40043 non-null  int64
#  1   Rating       40043 non-null  int64
#  2   Year_Month   40043 non-null  object
#  3   Review_Text  40043 non-null  object
#  4   user_id      40043 non-null  object
#  5   parks_id     40043 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review_ID    0 non-null      int64
#  1   Rating       0 non-null      int64
#  2   Year_Month   0 non-null      object
#  3   Review_Text  0 non-null      object
#  4   user_id      0 non-null      object
#  5   parks_id     0 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 0.0+ bytes

# %%
#Creamos un DataFrame para leer y almacenar en el un archivo CSV con los registros de los Usuarios
df2 = pd.read_csv('usuarios_random.csv')
df2.head()
# Out:
#        id      name    lname                 phone  \
# 0  U00001  Danielle    Gould      755.426.1903x842
# 1  U00002     Angel   Strong         (736)273-2022
# 2  U00003    Joshua   Warner  +1-271-117-5769x1716
# 3  U00004   Jeffrey   Cannon         (042)985-1448
# 4  U00005      Jill  Johnson    (983)052-1690x3922
#
#                          email
# 0           nathan82@gmail.com
# 1  antonio05@taylor-jordan.com
# 2           kweiss@perkins.com
# 3     fritzrebecca@hotmail.com
# 4       jeffreyweber@yahoo.com

# %%
#Agregamos la columna users_id a nuestro dataframe de reviews y le indicamos que va a llenar los registros de forma aleatoria con los datos de los id del dataframe de Usuarios
df1["user_id"] = np.random.choice(df2["id"], size=len(df1), replace=True)
df1.head()
# Out:
#    Review_ID  Rating Year_Month  \
# 0  670772142       4     2019-4
# 1  670682799       4     2019-5
# 2  670623270       4     2019-4
# 3  670607911       4     2019-4
# 4  670607296       4     2019-4
#
#                                          Review_Text user_id
# 0  If you've ever been to Disneyland anywhere you...  U05970
# 1  Its been a while since d last time we visit HK...  U07656
# 2  Thanks God it wasn   t too hot or too humid wh...  U06359
# 3  HK Disneyland is a great compact park. Unfortu...  U07196
# 4  the location is not in the city, took around 1...  U08280

# %%
#Creamos un DataFrame con 3 registros con la informacion de los parques de Disneyland
data = {
    "id": [1, 2, 3],
    "name": ["Hong Kong Disneyland", "California Disneyland", "Paris Disneyland"],
    "thematic": ["Magic Kingdom", "Magic Kingdom", "Magic Kingdom"],
    "location": ["Hong Kong", "California", "Paris"]
}

df_Parks = pd.DataFrame(data)
print(df_Parks)
# Out:
#    id                   name       thematic    location
# 0   1   Hong Kong Disneyland  Magic Kingdom   Hong Kong
# 1   2  California Disneyland  Magic Kingdom  California
# 2   3       Paris Disneyland  Magic Kingdom       Paris

# %%
#Creamos un DataFrame con 3 registros con la informacion de la locacion de los parques
data = {
    "address": ["Boulevard de Parc, Coupvray","1313 Disneyland Drive","Lantau Island"],
    "city": ["Paris","Anaheim","Lantau Island"],
    "state": ["Paris","California","Hong Kong"],
    "country": ["Francia","United States","China"]
}

df_LocationParks = pd.DataFrame(data)
print(df_LocationParks)
# Out:
#                        address           city       state        country
# 0  Boulevard de Parc, Coupvray          Paris       Paris        Francia
# 1        1313 Disneyland Drive        Anaheim  California  United States
# 2                Lantau Island  Lantau Island   Hong Kong          China

# %%
#Creamos un nuevo dataframe en el cual almacenamos los datos de los nombres de los parques del dataframe principal de reviews
df3 = pd.DataFrame(df['Branch'])
df3.info()

#Reemplazamos los nombres de los parques por el id del parque
df3['Branch'] = df3['Branch'].replace({'Disneyland_HongKong': '1'})
df3['Branch'] = df3['Branch'].replace({'Disneyland_California': '2'})
df3['Branch'] = df3['Branch'].replace({'Disneyland_Paris': '3'})
#Cambiamos el tipo de datos de Objeto por int
df3[['Branch']] = df3[['Branch']].astype("int")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Branch  42656 non-null  object
# dtypes: object(1)
# memory usage: 333.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Branch  42656 non-null  int64
# dtypes: int64(1)
# memory usage: 333.4 KB

# %%
df3.head()
# Out:
#    Branch
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#Agregamos la nueva columna parks_id con los id de los parques
df1['parks_id'] = df3['Branch'].values
df1.tail()
# Out:
#        Review_ID  Rating Year_Month  \
# 42651    1765031       5    missing
# 42652    1659553       5    missing
# 42653    1645894       5    missing
# 42654    1618637       4    missing
# 42655    1536786       4    missing
#
#                                              Review_Text user_id  parks_id
# 42651  i went to disneyland paris in july 03 and thou...  U03523         3
# 42652  2 adults and 1 child of 11 visited Disneyland ...  U09577         3
# 42653  My eleven year old daughter and myself went to...  U08041         3
# 42654  This hotel, part of the Disneyland Paris compl...  U05020         3
# 42655  I went to the Disneyparis resort, in 1996, wit...  U08675         3

# %% [markdown]
# # Insercion de Datos a MongoDB

# %%
#Una vez tenemos terminamos la manipulacion de los datos procedemos a subirlos a MongoDB
#Insercion de datos em la coleccion Reviews
collection.delete_many({})
records = df1.to_dict('records')
collection.insert_many(records)
print(f"Datos insertados: {len(records)} registros")
# Out:
# Datos insertados: 42656 registros

# %%
#Seleccionamos la coleccion usuarios
collection1 = db["users"]

#Insercion de datos en la coleccion users
collection1.delete_many({})
records = df2.to_dict('records')
collection1.insert_many(records)
print(f"Datos insertados: {len(records)} registros")
# Out:
# Datos insertados: 10000 registros

# %%
#Seleccionamos la coleccion parks
collection2 = db["parks"]

#Insercion de datos en la coleccion parks
collection2.delete_many({})
records = df_Parks.to_dict('records')
collection2.insert_many(records)
print(f"Datos insertados: {len(records)} registros")
# Out:
# InsertManyResult([ObjectId('6915738564eb08909ec56f15'), ObjectId('6915738564eb08909ec56f16'), ObjectId('6915738564eb08909ec56f17')], acknowledged=True)

# %%
#Seleccionamos la coleccion location
collection3 = db["location"]

#Insercion de datos en la coleccion location
collection3.delete_many({})
records = df_LocationParks.to_dict('records')
collection3.insert_many(records)
print(f"Datos insertados: {len(records)} registros")
# Out:
# Datos insertados: 3 registros
